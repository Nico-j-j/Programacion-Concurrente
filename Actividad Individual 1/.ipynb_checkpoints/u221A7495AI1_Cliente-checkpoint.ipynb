# %% [markdown]
# <!-- PROFILE LINK -->
#
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <h2 style = "text-align:center; font-size: 30px">ACTIVIDAD INDIVIDUAL 1</h2>
# <a href ="https://github.com/Nico-j-j">
# <img src="https://avatars.githubusercontent.com/u/55808829?s=400&v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Nicole Jealid Kuylen Aranda 221A7495">
# <a href ="https://github.com/Nico-j-j/Programacion-Concurrente">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M41" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %% [markdown]
# ## Enlace del repositorio: https://github.com/Nico-j-j/Programacion-Concurrente

# %% [markdown]
# ## Archivo Cliente

# %%
import threading
import sys
import socket
import pickle
import os

class Cliente():

    def __init__(self, host=input("Intoduzca la IP del servidor ?  "), port=int(input("Intoduzca el PUERTO del servidor ?  ")),nickname=input("Ingrese su nickname ? ")): #Se agrega un input más para colocar el nickname
        self.s = socket.socket()
        self.s.connect((host, int(port)))
        print('\n\tProceso con PID = ',os.getpid(), '\n\tHilo PRINCIPAL con ID =',threading.currentThread().getName(), '\n\tHilo en modo DAEMON = ', threading.currentThread().isDaemon(),'\n\tTotal Hilos activos en este punto del programa =', threading.active_count())
        threading.Thread(target=self.recibir, daemon=True).start()

        while True:
            msg =input('\nEscriba texto ?   ** Enviar = ENTER   ** Salir Chat = 1 \n')
            with open("u221A7495AI1.txt", "a") as f:
                f.write("\n" + nickname + " :" + msg)
                f.close()
            if msg != '1' : 
                msg =nickname+ " :  " + msg
                self.enviar(msg)
            else:
                print(" **** Me piro vampiro; cierro socket y mato al CLIENTE con PID = ", os.getpid())
                self.s.close()
                sys.exit()

    def recibir(self):
        print('\nHilo RECIBIR con ID =',threading.currentThread().getName(), '\n\tPertenece al PROCESO con PID', os.getpid(), "\n\tHilos activos TOTALES ", threading.active_count())
        while True:
            try:
                data = self.s.recv(64)
                if data: print(pickle.loads(data)) #Recibe como parámetro la data donde se van a leer los datos, y devuelve el objeto deserializado.
            except: pass

    def enviar(self, msg):
        self.s.send(pickle.dumps(msg)) #Envía el mensaje para que haya una comunicación.

arrancar = Cliente()

# %% [markdown]
# ## EJERCICIO A

# %% [markdown]
# ### Se ingresa la IP del servidor ‘192.168.56.1’, cuyo puerto es ‘17495’, de acuerdo con mi número de expediente ‘221A7495’.

# %%
from IPython import display
display.Image("Capturas/EjercicioA_parte1.png")

# %%
from IPython import display
display.Image("Capturas/EjercicioA_parte2.png")

# %% [markdown]
# ## EJERCICIO B y C

# %% [markdown]
# ### Tanto para el ejercicio B como para el ejercicio C, se han ejecutado 6 clientes con los siguientes nicknames: ‘221A7495@live.uem.es’, ‘Nicole’, ‘Alvaro’, ‘enana’, ‘Christian’ y ‘Carlos’. Para la pregunta B, cada cliente enviará un mensaje y dentro del servidor se mostrará cada mensaje enviado y qué cliente fue el que lo envió. Para la pregunta C será de la misma manera, solo que se le añade la funcionalidad de que imprima y muestre la lista de usuarios (nicknames) conectados en ese instante.

# %%
from IPython import display
display.Image("Capturas/EjercicioB-C.png")

# %% [markdown]
# ## EJERCICIO D

# %% [markdown]
# ### De acuerdo con las preguntas realizadas anteriormente, se ha implementado la funcionalidad de que el servidor almacene el historial de chat de todos los usuarios conectados en dicha sesión, por lo que se genera un archivo de texto, cuyo nombre tiene mi número de expediente ‘221A7495’.

# %%
from IPython import display
display.Image("Capturas/EjercicioD.png")
